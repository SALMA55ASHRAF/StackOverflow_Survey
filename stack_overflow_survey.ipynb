# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/survey_results_public.csv')

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.rename(columns={'ConvertedComp':'salary'},inplace=True) # change name of specific column

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 9           10  I am a developer by profession      Yes  22.0         14
# 32          33  I am a developer by profession      Yes  39.0         14
# 41          42  I am a developer by profession       No  32.0         14
# 46          47  I am a developer by profession      Yes  53.0         10
# 68          69  I am a developer by profession      Yes  25.0         12
#
#    CompFreq  CompTotal    salary         Country          CurrencyDesc  ...  \
# 9    Yearly    25000.0   32315.0  United Kingdom        Pound sterling  ...
# 32  Monthly     4900.0   63564.0         Belgium         European Euro  ...
# 41   Yearly   130000.0  130000.0   United States  United States dollar  ...
# 46   Yearly    58000.0   74970.0  United Kingdom        Pound sterling  ...
# 68   Yearly   550000.0  594539.0          France         European Euro  ...
#
#                     SurveyEase           SurveyLength Trans  \
# ...

# %%
df['Hobbyist']=df['Hobbyist'].map({'Yes':True,'No':False})

# %%
df.head()
# Out:
#     Respondent                      MainBranch  Hobbyist   Age Age1stCode  \
# 9           10  I am a developer by profession      True  22.0         14
# 32          33  I am a developer by profession      True  39.0         14
# 41          42  I am a developer by profession     False  32.0         14
# 46          47  I am a developer by profession      True  53.0         10
# 68          69  I am a developer by profession      True  25.0         12
#
#    CompFreq  CompTotal    salary         Country          CurrencyDesc  ...  \
# 9    Yearly    25000.0   32315.0  United Kingdom        Pound sterling  ...
# 32  Monthly     4900.0   63564.0         Belgium         European Euro  ...
# 41   Yearly   130000.0  130000.0   United States  United States dollar  ...
# 46   Yearly    58000.0   74970.0  United Kingdom        Pound sterling  ...
# 68   Yearly   550000.0  594539.0          France         European Euro  ...
#
#                     SurveyEase           SurveyLength Trans  \
# ...

# %%
df.shape
# Out:
# (4213, 61)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4213 entries, 9 to 63517
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    4213 non-null   int64
#  1   MainBranch                    4213 non-null   object
#  2   Hobbyist                      4213 non-null   bool
#  3   Age                           4213 non-null   float64
#  4   Age1stCode                    4213 non-null   object
#  5   CompFreq                      4213 non-null   object
#  6   CompTotal                     4213 non-null   float64
#  7   salary                        4213 non-null   float64
#  8   Country                       4213 non-null   object
#  9   CurrencyDesc                  4213 non-null   object
#  10  CurrencySymbol                4213 non-null   object
#  11  DatabaseDesireNextYear        4213 non-null   object
# ...

# %%
df.describe()
# Out:
#          Respondent          Age     CompTotal        salary  WorkWeekHrs
# count   4213.000000  4213.000000  4.213000e+03  4.213000e+03  4213.000000
# mean   27533.329694    32.072158  2.740265e+06  1.116038e+05    41.265523
# std    18439.176546     7.482935  4.297804e+07  2.459682e+05    15.344240
# min       10.000000    17.000000  0.000000e+00  0.000000e+00     2.000000
# 25%    12200.000000    26.000000  3.000000e+04  3.037200e+04    40.000000
# 50%    24863.000000    31.000000  7.200000e+04  6.050500e+04    40.000000
# 75%    46016.000000    36.000000  1.300000e+05  1.000000e+05    45.000000
# max    64938.000000    70.000000  1.900000e+09  2.000000e+06   425.000000

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4213 entries, 9 to 63517
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    4213 non-null   int64
#  1   MainBranch                    4213 non-null   object
#  2   Hobbyist                      4213 non-null   bool
#  3   Age                           4213 non-null   float64
#  4   Age1stCode                    4213 non-null   object
#  5   CompFreq                      4213 non-null   object
#  6   CompTotal                     4213 non-null   float64
#  7   salary                        4213 non-null   float64
#  8   Country                       4213 non-null   object
#  9   CurrencyDesc                  4213 non-null   object
#  10  CurrencySymbol                4213 non-null   object
#  11  DatabaseDesireNextYear        4213 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'salary', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
corr=df.corr()
import seaborn as sns
sns.heatmap(corr,annot=True)
# Out:
# <ipython-input-19-b909868f6b1b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %%
df.describe(include='O')
# Out:
#                             MainBranch Age1stCode CompFreq        Country  \
# count                             4213       4213     4213           4213
# unique                               2         34        3            123
# top     I am a developer by profession         12   Yearly  United States
# freq                              3982        487     2538           1089
#
#                 CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# count                   4213           4213                   4213
# unique                    95             95                   1062
# top     United States dollar            USD   Microsoft SQL Server
# freq                    1189           1189                    228
#
#           DatabaseWorkedWith                DevType  \
# count                   4213                   4213
# unique                   994                   1537
# top     Microsoft SQL Server  Developer, full-stack
# ...

# %%
df.loc[[9]]
# Out:
#    Respondent                      MainBranch  Hobbyist   Age Age1stCode  \
# 9          10  I am a developer by profession      True  22.0         14
#
#   CompFreq  CompTotal   salary         Country    CurrencyDesc  ...  \
# 9   Yearly    25000.0  32315.0  United Kingdom  Pound sterling  ...
#
#   SurveyEase           SurveyLength Trans             UndergradMajor  \
# 9       Easy  Appropriate in length    No  Mathematics or statistics
#
#   WebframeDesireNextYear WebframeWorkedWith  \
# 9           Flask;jQuery       Flask;jQuery
#
#                               WelcomeChange WorkWeekHrs YearsCode YearsCodePro
# 9  Somewhat more welcome now than last year        36.0         8            4
#
# [1 rows x 61 columns]

# %%
scheme=pd.read_csv('/content/survey_results_schema.csv')

# %%
scheme.loc[scheme['Column']=='Hobbyist']
# Out:
#      Column             QuestionText
# 2  Hobbyist  Do you code as a hobby?

# %%
scheme.columns
# Out:
# Index(['Column', 'QuestionText'], dtype='object')

# %%
for i in range(60):
      print(scheme['Column'][i]+': ' ,scheme['QuestionText'][i])
# Out:
# Respondent:  Randomized respondent ID number (not in order of survey response time)
# MainBranch:  Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
# Hobbyist:  Do you code as a hobby?
# Age:  What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# Age1stCode:  At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)
# CompFreq:  Is that compensation weekly, monthly, or yearly?
# CompTotal:  What is your current total compensation (salary, bonuses, and perks, before taxes and deductions), in `CurrencySymbol`? Please enter a whole number in the box below, without any punctuation. If you are paid hourly, please estimate an equivalent weekly, monthly, or yearly salary. If you prefer not to answer, please leave the box empty.
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# True     3512
# False     701
# Name: Hobbyist, dtype: int64

# %%
df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   3982
# I am not primarily a developer, but I write code sometimes as part of my work     231
# Name: MainBranch, dtype: int64

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'salary', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Age'].value_counts()
# Out:
# 28.0    272
# 30.0    263
# 25.0    255
# 29.0    252
# 26.0    248
# 27.0    247
# 31.0    216
# 24.0    208
# 32.0    205
# 35.0    184
# 33.0    178
# 34.0    174
# 23.0    157
# 36.0    127
# 37.0    125
# 38.0    118
# 39.0    115
# 22.0    114
# 40.0    107
# 42.0     77
# 41.0     71
# 43.0     70
# 45.0     61
# 21.0     53
# 44.0     43
# 48.0     35
# 46.0     34
# 47.0     25
# 49.0     25
# 50.0     23
# 51.0     18
# 20.0     17
# 52.0     15
# 53.0     13
# 55.0     11
# 54.0     10
# 19.0     10
# 56.0      8
# 58.0      6
# 59.0      6
# 57.0      5
# 18.0      3
# 60.0      2
# 63.0      2
# 61.0      2
# 66.0      1
# 70.0      1
# 17.0      1
# Name: Age, dtype: int64

# %%
df['Age1stCode'].value_counts()
# Out:
# 12                      487
# 14                      456
# 15                      443
# 16                      406
# 13                      331
# 18                      329
# 10                      311
# 17                      256
# 11                      211
# 19                      178
# 8                       149
# 20                      115
# 9                       101
# 7                        81
# 21                       62
# 6                        50
# 22                       46
# 23                       39
# 25                       32
# 24                       27
# 5                        23
# Younger than 5 years     20
# 26                       18
# 28                       11
# 27                        9
# 32                        5
# 30                        4
# 31                        4
# 29                        3
# 39                        2
# 40                        1
# 38                        1
# 33                        1
# ...

# %%
df['DatabaseWorkedWith'].value_counts()
# Out:
# Microsoft SQL Server                                                               340
# MySQL                                                                              117
# PostgreSQL                                                                         111
# Microsoft SQL Server;MySQL                                                          95
# MongoDB                                                                             74
#                                                                                   ...
# IBM DB2;Microsoft SQL Server;MySQL;Redis                                             1
# Elasticsearch;Microsoft SQL Server;MongoDB;MySQL;Oracle;PostgreSQL;Redis;SQLite      1
# Firebase;MongoDB;Redis                                                               1
# IBM DB2;Microsoft SQL Server;MongoDB;Redis;SQLite                                    1
# DynamoDB;Elasticsearch;MongoDB;MySQL;Oracle;PostgreSQL;Redis                         1
# ...

# %%
df['Gender'].value_counts()
# Out:
# Man                                                            4018
# Woman                                                           165
# Non-binary, genderqueer, or gender non-conforming                17
# Man;Non-binary, genderqueer, or gender non-conforming             9
# Woman;Non-binary, genderqueer, or gender non-conforming           2
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       2
# Name: Gender, dtype: int64

# %%
df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)              2263
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            997
# Some college/university study without earning a degree     640
# Associate degree (A.A., A.S., etc.)                        161
# Other doctoral degree (Ph.D., Ed.D., etc.)                  87
# Professional degree (JD, MD, etc.)                          65
# Name: EdLevel, dtype: int64

# %%
df['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                        415
# Developer, back-end;Developer, front-end;Developer, full-stack                                                                                                                               232
# Developer, back-end                                                                                                                                                                          140
# Developer, back-end;Developer, full-stack                                                                                                                                                    129
# Developer, back-end;Developer, desktop or enterprise applications;Developer, front-end;Developer, full-stack                                                                                  91
# ...

# %%
df['LanguageWorkedWith'].value_counts()
# Out:
# C#;HTML/CSS;JavaScript;SQL;TypeScript                                             126
# C#;HTML/CSS;JavaScript;SQL                                                        123
# Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL;TypeScript                        77
# HTML/CSS;JavaScript;PHP;SQL                                                        68
# Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;SQL                                   51
#                                                                                  ...
# Bash/Shell/PowerShell;C;Go;HTML/CSS;JavaScript;Python;Ruby;Rust;SQL;TypeScript      1
# Bash/Shell/PowerShell;JavaScript;Ruby;SQL;TypeScript                                1
# C;C#                                                                                1
# Bash/Shell/PowerShell;Python;Scala;SQL                                              1
# Assembly;C;C++;HTML/CSS;Java;JavaScript;PHP;Python;Ruby;SQL                         1
# ...

# %%
df['Employment'].value_counts()
# Out:
# Employed full-time    4100
# Employed part-time     113
# Name: Employment, dtype: int64

# %%
df['Ethnicity'].value_counts()
# Out:
# White or of European descent                                                                                                                          2853
# South Asian                                                                                                                                            323
# Hispanic or Latino/a/x                                                                                                                                 259
# Middle Eastern                                                                                                                                         138
# Southeast Asian                                                                                                                                        117
#                                                                                                                                                       ...
# ...

# %%
df['JobSeek'].value_counts()
# Out:
# I’m not actively looking, but I am open to new opportunities    2617
# I am not interested in new job opportunities                    1119
# I am actively looking for a job                                  477
# Name: JobSeek, dtype: int64

# %%
df['JobSat'].value_counts()
# Out:
# Very satisfied                        1542
# Slightly satisfied                    1362
# Slightly dissatisfied                  620
# Neither satisfied nor dissatisfied     414
# Very dissatisfied                      275
# Name: JobSat, dtype: int64

# %%
df['PlatformWorkedWith'].value_counts()
# Out:
# Windows                                                                                                  168
# Microsoft Azure;Windows                                                                                  145
# Linux;Windows                                                                                             69
# Docker;Linux;Windows                                                                                      58
# Microsoft Azure                                                                                           58
#                                                                                                         ...
# Android;AWS;Docker;Heroku;iOS;Kubernetes;Linux;MacOS;Microsoft Azure;Windows                               1
# Android;AWS;Docker;iOS;Kubernetes;Linux;MacOS                                                              1
# AWS;Slack Apps and Integrations                                                                            1
# ...

# %%
df['MiscTechWorkedWith'].value_counts()
# Out:
# Node.js                                                                                           705
# .NET;.NET Core                                                                                    422
# .NET;.NET Core;Node.js                                                                            255
# .NET                                                                                              155
# Node.js;React Native                                                                              146
#                                                                                                  ...
# .NET;Flutter;TensorFlow                                                                             1
# Ansible;Apache Spark;Hadoop;Pandas                                                                  1
# Apache Spark;Hadoop;Node.js;Pandas;TensorFlow;Teraform;Torch/PyTorch;Unity 3D                       1
# ...

# %%
df['NEWDevOps'].value_counts() #Does your company have a dedicated DevOps person
# Out:
# No          2160
# Yes         1819
# Not sure     234
# Name: NEWDevOps, dtype: int64

# %%
df['NEWLearn'].value_counts()
# Out:
# Once a year             1751
# Every few months        1628
# Once every few years     798
# Once a decade             36
# Name: NEWLearn, dtype: int64

# %%
df['YearsCode'].value_counts()
# Out:
# 10                    360
# 20                    277
# 15                    262
# 12                    236
# 8                     229
# 7                     222
# 6                     215
# 9                     188
# 5                     170
# 13                    166
# 11                    165
# 16                    155
# 14                    141
# 25                    140
# 18                    126
# 4                     114
# 30                    109
# 22                    105
# 17                    101
# 19                     83
# 23                     65
# 21                     53
# 3                      52
# 35                     46
# 24                     43
# 27                     41
# 26                     40
# 28                     33
# 32                     32
# 37                     29
# 40                     28
# 29                     25
# 33                     23
# 34                     23
# 2                      21
# ...

# %%
df['YearsCodePro'].value_counts()
# Out:
# 3                   420
# 5                   384
# 4                   335
# 6                   305
# 2                   301
# 10                  268
# 8                   259
# 7                   243
# 15                  169
# 12                  166
# 20                  155
# 9                   142
# 11                  134
# 1                   127
# 13                  100
# 16                   86
# 14                   82
# Less than 1 year     69
# 18                   61
# 17                   52
# 25                   48
# 19                   47
# 22                   47
# 21                   42
# 23                   36
# 24                   25
# 30                   22
# 26                   21
# 35                   11
# 32                   11
# 28                    9
# 27                    6
# 31                    6
# 29                    6
# 33                    5
# 36                    4
# 37                    3
# 34                    2
# ...
